# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('delhi_houseprice.csv')
df
# Out:
#          Area  BHK  Bathroom      Furnishing  \
# 0       800.0    3       2.0  Semi-Furnished
# 1       750.0    2       2.0  Semi-Furnished
# 2       950.0    2       2.0       Furnished
# 3       600.0    2       2.0  Semi-Furnished
# 4       650.0    2       2.0  Semi-Furnished
# ...       ...  ...       ...             ...
# 1254   4118.0    4       5.0     Unfurnished
# 1255   1050.0    3       2.0  Semi-Furnished
# 1256    875.0    3       3.0  Semi-Furnished
# 1257    990.0    2       2.0     Unfurnished
# 1258  11050.0    3       3.0     Unfurnished
#
#                                                Locality  Parking     Price  \
# 0                                      Rohini Sector 25      1.0   6500000
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# ...

# %%
df.shape
# Out:
# (1259, 11)

# %%
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.tail()
# Out:
#          Area  BHK  Bathroom      Furnishing                   Locality  \
# 1254   4118.0    4       5.0     Unfurnished          Chittaranjan Park
# 1255   1050.0    3       2.0  Semi-Furnished          Chittaranjan Park
# 1256    875.0    3       3.0  Semi-Furnished          Chittaranjan Park
# 1257    990.0    2       2.0     Unfurnished  Chittaranjan Park Block A
# 1258  11050.0    3       3.0     Unfurnished          Chittaranjan Park
#
#       Parking     Price         Status   Transaction           Type  Per_Sqft
# 1254      3.0  55000000  Ready_to_move  New_Property  Builder_Floor   12916.0
# 1255      3.0  12500000  Ready_to_move        Resale  Builder_Floor   12916.0
# 1256      3.0  17500000  Ready_to_move  New_Property  Builder_Floor   12916.0
# 1257      1.0  11500000  Ready_to_move        Resale  Builder_Floor   12916.0
# 1258      1.0  18500000  Ready_to_move  New_Property  Builder_Floor   12916.0

# %%
columns_to_drop = ['Furnishing', 'Parking', 'Status', 'Transaction', 'Type', 'Per_Sqft']
df = df.drop(columns=columns_to_drop)

# Display the updated DataFrame
print(df.head())
# Out:
#     Area  BHK  Bathroom                                           Locality  \
# 0  800.0    3       2.0                                   Rohini Sector 25
# 1  750.0    2       2.0             J R Designers Floors, Rohini Sector 24
# 2  950.0    2       2.0                Citizen Apartment, Rohini Sector 13
# 3  600.0    2       2.0                                   Rohini Sector 24
# 4  650.0    2       2.0  Rohini Sector 24 carpet area 650 sqft status R...
#
#       Price
# 0   6500000
# 1   5000000
# 2  15500000
# 3   4200000
# 4   6200000

# %%
df
# Out:
#          Area  BHK  Bathroom  \
# 0       800.0    3       2.0
# 1       750.0    2       2.0
# 2       950.0    2       2.0
# 3       600.0    2       2.0
# 4       650.0    2       2.0
# ...       ...  ...       ...
# 1254   4118.0    4       5.0
# 1255   1050.0    3       2.0
# 1256    875.0    3       3.0
# 1257    990.0    2       2.0
# 1258  11050.0    3       3.0
#
#                                                Locality     Price
# 0                                      Rohini Sector 25   6500000
# 1                J R Designers Floors, Rohini Sector 24   5000000
# 2                   Citizen Apartment, Rohini Sector 13  15500000
# 3                                      Rohini Sector 24   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...   6200000
# ...                                                 ...       ...
# 1254                                  Chittaranjan Park  55000000
# 1255                                  Chittaranjan Park  12500000
# ...

# %%
df.isnull().sum()
# Out:
# Area        0
# BHK         0
# Bathroom    2
# Locality    0
# Price       0
# dtype: int64

# %%
mode = df["Bathroom"].mode()
mode
# Out:
# 0    2.0
# Name: Bathroom, dtype: float64

# %%
df["Bathroom"].fillna(2.0, inplace=True)
df
# Out:
#          Area  BHK  Bathroom  \
# 0       800.0    3       2.0
# 1       750.0    2       2.0
# 2       950.0    2       2.0
# 3       600.0    2       2.0
# 4       650.0    2       2.0
# ...       ...  ...       ...
# 1254   4118.0    4       5.0
# 1255   1050.0    3       2.0
# 1256    875.0    3       3.0
# 1257    990.0    2       2.0
# 1258  11050.0    3       3.0
#
#                                                Locality     Price
# 0                                      Rohini Sector 25   6500000
# 1                J R Designers Floors, Rohini Sector 24   5000000
# 2                   Citizen Apartment, Rohini Sector 13  15500000
# 3                                      Rohini Sector 24   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...   6200000
# ...                                                 ...       ...
# 1254                                  Chittaranjan Park  55000000
# 1255                                  Chittaranjan Park  12500000
# ...

# %%
df.isnull().sum()
# Out:
# Area        0
# BHK         0
# Bathroom    0
# Locality    0
# Price       0
# dtype: int64

# %%
duplicates=df[df.duplicated()]
duplicates
# Out:
#         Area  BHK  Bathroom  \
# 84    1540.0    3       3.0
# 92    1450.0    3       3.0
# 93    1260.0    3       3.0
# 94    2925.0    4       4.0
# 96    1600.0    3       3.0
# ...      ...  ...       ...
# 1164  1300.0    2       2.0
# 1165  1200.0    2       2.0
# 1166  1300.0    3       2.0
# 1167  1400.0    3       3.0
# 1168  1400.0    3       3.0
#
#                                                Locality     Price
# 84               Nav Kairali Apartment, Dwarka Sector 3  14500000
# 92                                       Lajpat Nagar 3  30000000
# 93                                       Lajpat Nagar 3  21000000
# 94                                       Lajpat Nagar 3  57500000
# 96                                       Lajpat Nagar 3  30000000
# ...                                                 ...       ...
# 1164                        Yamuna Apartment, Alaknanda  15000000
# 1165                       Nilgiri Apartment, Alaknanda  14300000
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#          Area  BHK  Bathroom  \
# 0       800.0    3       2.0
# 1       750.0    2       2.0
# 2       950.0    2       2.0
# 3       600.0    2       2.0
# 4       650.0    2       2.0
# ...       ...  ...       ...
# 1254   4118.0    4       5.0
# 1255   1050.0    3       2.0
# 1256    875.0    3       3.0
# 1257    990.0    2       2.0
# 1258  11050.0    3       3.0
#
#                                                Locality     Price
# 0                                      Rohini Sector 25   6500000
# 1                J R Designers Floors, Rohini Sector 24   5000000
# 2                   Citizen Apartment, Rohini Sector 13  15500000
# 3                                      Rohini Sector 24   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...   6200000
# ...                                                 ...       ...
# 1254                                  Chittaranjan Park  55000000
# 1255                                  Chittaranjan Park  12500000
# ...

# %%
df.rename(columns={'Locality': 'location'}, inplace=True)
df
# Out:
#          Area  BHK  Bathroom  \
# 0       800.0    3       2.0
# 1       750.0    2       2.0
# 2       950.0    2       2.0
# 3       600.0    2       2.0
# 4       650.0    2       2.0
# ...       ...  ...       ...
# 1254   4118.0    4       5.0
# 1255   1050.0    3       2.0
# 1256    875.0    3       3.0
# 1257    990.0    2       2.0
# 1258  11050.0    3       3.0
#
#                                                location     Price
# 0                                      Rohini Sector 25   6500000
# 1                J R Designers Floors, Rohini Sector 24   5000000
# 2                   Citizen Apartment, Rohini Sector 13  15500000
# 3                                      Rohini Sector 24   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...   6200000
# ...                                                 ...       ...
# 1254                                  Chittaranjan Park  55000000
# 1255                                  Chittaranjan Park  12500000
# ...

# %%
df['location'].unique()
# Out:
# array(['Rohini Sector 25', 'J R Designers Floors, Rohini Sector 24',
#        'Citizen Apartment, Rohini Sector 13', 'Rohini Sector 24',
#        'Rohini Sector 24 carpet area 650 sqft status Ready to Move floor 4 out of 4 floors transaction New Property furnishing Semi-Furnished facing East overlooking Garden/Park, Main Road car parking 1 Open bathroom 2 balcony 1 ownership Freehold Newly Constructed Property Newly Constructed Property East Facing Property 2BHK Newly build property for Sale. A House is waiting for a Friendly Family to make it a lovely home.So please come and make his house feel alive once again. read more Contact Agent View Phone No. Share Feedback Garima properties Certified Agent Trusted by Users Genuine Listings Market Knowledge',
#        'Delhi Homes, Rohini Sector 24', 'Rohini Sector 21',
#        'Rohini Sector 22', 'Rohini Sector 20',
# ...

# %%
df['location'].value_counts()
# Out:
# location
# Kailash Colony, Greater Kailash                29
# Yamuna Vihar, Shahdara                         28
# J R Designers Floors, Rohini Sector 24         27
# Lajpat Nagar 3                                 26
# Lajpat Nagar 2                                 25
#                                                ..
# Vasant Kunj Sector B                            1
# DDA Pocket 1, Vasant Kunj Sector D              1
# Kishangarh, Vasant Kunj                         1
# DDA Flats Vasant Kunj, Vasant Kunj Sector C     1
# Chittaranjan Park Block A                       1
# Name: count, Length: 365, dtype: int64

# %%
df['location'] = df['location'].apply(lambda x: x.strip())
location_count = df['location'].value_counts()

# %%
location_count_less_10 = location_count[location_count<=10]
location_count_less_10
# Out:
# location
# Mahavir Enclave                                10
# Alaknanda                                      10
# New Manglapuri, Sultanpur                      10
# Govindpuri Extension, Kalkaji                   9
# Rohini Sector 24                                9
#                                                ..
# Vasant Kunj Sector B                            1
# DDA Pocket 1, Vasant Kunj Sector D              1
# Kishangarh, Vasant Kunj                         1
# DDA Flats Vasant Kunj, Vasant Kunj Sector C     1
# Chittaranjan Park Block A                       1
# Name: count, Length: 340, dtype: int64

# %%
df['location'] = df['location'].apply(lambda x: 'other' if x in location_count_less_10 else x)

# %%
df
# Out:
#          Area  BHK  Bathroom                                location     Price
# 0       800.0    3       2.0                                   other   6500000
# 1       750.0    2       2.0  J R Designers Floors, Rohini Sector 24   5000000
# 2       950.0    2       2.0                                   other  15500000
# 3       600.0    2       2.0                                   other   4200000
# 4       650.0    2       2.0                                   other   6200000
# ...       ...  ...       ...                                     ...       ...
# 1254   4118.0    4       5.0                       Chittaranjan Park  55000000
# 1255   1050.0    3       2.0                       Chittaranjan Park  12500000
# 1256    875.0    3       3.0                       Chittaranjan Park  17500000
# 1257    990.0    2       2.0                                   other  11500000
# 1258  11050.0    3       3.0                       Chittaranjan Park  18500000
#
# [1140 rows x 5 columns]

# %%
df['location'].value_counts()
# Out:
# location
# other                                                           683
# Kailash Colony, Greater Kailash                                  29
# Yamuna Vihar, Shahdara                                           28
# J R Designers Floors, Rohini Sector 24                           27
# Lajpat Nagar 3                                                   26
# Lajpat Nagar 2                                                   25
# Chittaranjan Park                                                24
# Laxmi Nagar                                                      22
# Mehrauli                                                         21
# Saket                                                            21
# DDA Flats Sarita Vihar, Sarita Vihar, Mathura Road               19
# Safdarjung Enclave                                               18
# Chhattarpur                                                      17
# Sheikh Sarai Phase 1                                             16
# ...

# %%
df['location'].unique()
# Out:
# array(['other', 'J R Designers Floors, Rohini Sector 24',
#        'Lajpat Nagar 2', 'Lajpat Nagar 3', 'The Amaryllis, Karol Bagh',
#        'New Friends Colony', 'Kailash Colony, Greater Kailash',
#        'Yamuna Vihar, Shahdara', 'Laxmi Nagar', 'Patel Nagar West',
#        'Sukhdev Vihar, Okhla', 'Saket', 'Safdarjung Enclave',
#        'Common Wealth Games Village, Commonwealth Games Village 2010',
#        'DDA Flats Sarita Vihar, Sarita Vihar, Mathura Road',
#        'Chhattarpur', 'Mehrauli', 'Mahavir Enclave Part 1',
#        'Malviya Nagar', 'Dilshad Colony, Dilshad Garden',
#        'Vasundhara Enclave',
#        'DLF Capital Greens, New Moti Nagar, Kirti Nagar',
#        'New Moti Nagar, Kirti Nagar', 'Sheikh Sarai Phase 1', 'Hauz Khas',
#        'Chittaranjan Park'], dtype=object)

# %%
location_mapping = {
    'other': 1,
    'J R Designers Floors, Rohini Sector 24': 2,
    'Lajpat Nagar 2': 3,
    'Lajpat Nagar 3': 4,
    'The Amaryllis, Karol Bagh': 5,
    'New Friends Colony': 6,
    'Kailash Colony, Greater Kailash': 7,
    'Yamuna Vihar, Shahdara': 8,
    'Laxmi Nagar': 9,
    'Patel Nagar West': 10,
    'Sukhdev Vihar, Okhla': 11,
    'Saket': 12,
    'Safdarjung Enclave': 13,
    'Common Wealth Games Village, Commonwealth Games Village 2010': 14,
    'DDA Flats Sarita Vihar, Sarita Vihar, Mathura Road': 15,
    'Chhattarpur': 16,
    'Mehrauli': 17,
    'Mahavir Enclave Part 1': 18,
    'Malviya Nagar': 19,
    'Dilshad Colony, Dilshad Garden': 20,
    'Vasundhara Enclave': 21,
    'DLF Capital Greens, New Moti Nagar, Kirti Nagar': 22,
    'New Moti Nagar, Kirti Nagar': 23,
    'Sheikh Sarai Phase 1': 24,
    'Hauz Khas': 25,
    'Chittaranjan Park': 26
}

df['location_encoding'] = df['location'].map(location_mapping)
df[['location','location_encoding']]
# Out:
#                                     location  location_encoding
# 0                                      other                  1
# 1     J R Designers Floors, Rohini Sector 24                  2
# 2                                      other                  1
# 3                                      other                  1
# 4                                      other                  1
# ...                                      ...                ...
# 1254                       Chittaranjan Park                 26
# 1255                       Chittaranjan Park                 26
# 1256                       Chittaranjan Park                 26
# 1257                                   other                  1
# 1258                       Chittaranjan Park                 26
#
# [1140 rows x 2 columns]

# %%
df
# Out:
#          Area  BHK  Bathroom                                location  \
# 0       800.0    3       2.0                                   other
# 1       750.0    2       2.0  J R Designers Floors, Rohini Sector 24
# 2       950.0    2       2.0                                   other
# 3       600.0    2       2.0                                   other
# 4       650.0    2       2.0                                   other
# ...       ...  ...       ...                                     ...
# 1254   4118.0    4       5.0                       Chittaranjan Park
# 1255   1050.0    3       2.0                       Chittaranjan Park
# 1256    875.0    3       3.0                       Chittaranjan Park
# 1257    990.0    2       2.0                                   other
# 1258  11050.0    3       3.0                       Chittaranjan Park
#
#          Price  location_encoding
# 0      6500000                  1
# 1      5000000                  2
# ...

# %%
columns_to_drop = ['location']
df = df.drop(columns=columns_to_drop)
df
# Out:
#          Area  BHK  Bathroom     Price  location_encoding
# 0       800.0    3       2.0   6500000                  1
# 1       750.0    2       2.0   5000000                  2
# 2       950.0    2       2.0  15500000                  1
# 3       600.0    2       2.0   4200000                  1
# 4       650.0    2       2.0   6200000                  1
# ...       ...  ...       ...       ...                ...
# 1254   4118.0    4       5.0  55000000                 26
# 1255   1050.0    3       2.0  12500000                 26
# 1256    875.0    3       3.0  17500000                 26
# 1257    990.0    2       2.0  11500000                  1
# 1258  11050.0    3       3.0  18500000                 26
#
# [1140 rows x 5 columns]

# %%
df.rename(columns={'location_encoding': 'location'}, inplace=True)
df
# Out:
#          Area  BHK  Bathroom     Price  location
# 0       800.0    3       2.0   6500000         1
# 1       750.0    2       2.0   5000000         2
# 2       950.0    2       2.0  15500000         1
# 3       600.0    2       2.0   4200000         1
# 4       650.0    2       2.0   6200000         1
# ...       ...  ...       ...       ...       ...
# 1254   4118.0    4       5.0  55000000        26
# 1255   1050.0    3       2.0  12500000        26
# 1256    875.0    3       3.0  17500000        26
# 1257    990.0    2       2.0  11500000         1
# 1258  11050.0    3       3.0  18500000        26
#
# [1140 rows x 5 columns]

# %%
df.to_csv("Cleaned_data.csv")

# %%
output_data=df["Price"]
output_data
# Out:
# 0        6500000
# 1        5000000
# 2       15500000
# 3        4200000
# 4        6200000
#           ...
# 1254    55000000
# 1255    12500000
# 1256    17500000
# 1257    11500000
# 1258    18500000
# Name: Price, Length: 1140, dtype: int64

# %%
input_data=df.drop('Price', axis=1)
input_data
# Out:
#          Area  BHK  Bathroom  location
# 0       800.0    3       2.0         1
# 1       750.0    2       2.0         2
# 2       950.0    2       2.0         1
# 3       600.0    2       2.0         1
# 4       650.0    2       2.0         1
# ...       ...  ...       ...       ...
# 1254   4118.0    4       5.0        26
# 1255   1050.0    3       2.0        26
# 1256    875.0    3       3.0        26
# 1257    990.0    2       2.0         1
# 1258  11050.0    3       3.0        26
#
# [1140 rows x 4 columns]

# %%
X_train,x_test,Y_train,y_test=train_test_split(input_data,output_data,test_size=0.20,random_state=42)

# %%
X_train.shape
# Out:
# (912, 4)

# %%
x_test.shape
# Out:
# (228, 4)

# %%
models = {
    "                     Linear Regression": LinearRegression(),
    " Linear Regression (L2 Regularization)": Ridge(),
    " Linear Regression (L1 Regularization)": Lasso()
    }

for name, model in models.items():
    model.fit(X_train, Y_train)
    print(name + " trained.")
# Out:
#                      Linear Regression trained.
#  Linear Regression (L2 Regularization) trained.
#  Linear Regression (L1 Regularization) trained.

# %%
for name, model in models.items():
    print(name + " R^2 Score: {:.5f}".format(model.score(x_test, y_test)))
# Out:
#                      Linear Regression R^2 Score: 0.64195
#  Linear Regression (L2 Regularization) R^2 Score: 0.64198
#  Linear Regression (L1 Regularization) R^2 Score: 0.64195

# %%
import joblib

# %%
joblib.dump(models,"delhi_price_predictor")
# Out:
# ['delhi_price_predictor']
